# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-100, 100, 1)
y = x ** 2
plt.plot(x, y)
plt.show()

# %%
y1 = x ** 2
y2 = x ** 3
y3 = -x ** 2
y4 = -x ** 3
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.show()

# %%
y1 = x ** 2
y2 = x ** 3
y3 = -x ** 2
y4 = -x ** 3
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.subplot(1, 2, 2)
plt.plot(x, y2)
plt.subplot(2, 2, 3)
plt.plot(x, y3)
#plt.subplot(2, 2, 4)
#plt.plot(x, y4)
plt.show()

# %%
y1 = x ** 2
y2 = x ** 3
y3 = -x ** 2
y4 = -x ** 3

figura = plt.figure(figsize = (10, 10))

figura.add_subplot(2, 2, 1)
plt.plot(x, y1)
figura.add_subplot(1, 2, 2)
plt.plot(x, y2)
figura.add_subplot(2, 2, 3)
plt.plot(x, y3)
#figura.add_subplot(2, 2, 4)
#plt.plot(x, y4)
plt.show()

# %%
y1 = x ** 2
y2 = x ** 3
y3 = -x ** 2
y4 = -x ** 3
y = [y1, y2, y3, y4]

figura = plt.figure(figsize = (20, 10))

for i in range(4):
    figura.add_subplot(2, 2, i + 1)
    plt.plot(x, y[i])
plt.show()

# %% [markdown]
# ### Imagens

# %%
from skimage import io
from skimage.io import imread
from IPython.display import Image, display

# %%
imagem = imread('imagem/img1.png')
plt.imshow(imagem)
plt.show()

# %%
endereco = '/home/tiago/Data-Science/Python-para-Machine-Learning/imagem'
imagens = []

for i in range(4):
    imagem = imread(endereco+'img'+str(i+1)+'.png')
    imagens.append(imagem)

# %%
figure = plt.figure(figsize = (15, 8))

for i in range(4):
    figura.add_subplot(2, 2, i + 1)
    plt.imshow(imagens[i])
plt.show()
